# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/amazon-fine-food-reviews/Reviews.csv
# /kaggle/input/amazon-fine-food-reviews/hashes.txt
# /kaggle/input/amazon-fine-food-reviews/database.sqlite
# /kaggle/input/ayyonina/solution.csv
# /kaggle/input/hinaguhey/Sample_Submission.csv
# /kaggle/input/hinaguhey/train.csv
# /kaggle/input/hinaguhey/test.csv

# %%
import tensorflow as tf
import os
from tensorflow.python.keras.layers import Layer
from tensorflow.python.keras import backend as K


class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state """

            assert_msg = "States must be a list. However states {} is of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch_size*en_seq_len, latent_dim
            reshaped_enc_outputs = K.reshape(encoder_out_seq, (-1, en_hidden))
            # <= batch_size*en_seq_len, latent_dim
            W_a_dot_s = K.reshape(K.dot(reshaped_enc_outputs, self.W_a), (-1, en_seq_len, en_hidden))
            if verbose:
                print('wa.s>',W_a_dot_s.shape)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>',U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            reshaped_Ws_plus_Uh = K.tanh(K.reshape(W_a_dot_s + U_a_dot_h, (-1, en_hidden)))
            if verbose:
                print('Ws+Uh>', reshaped_Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.reshape(K.dot(reshaped_Ws_plus_Uh, self.V_a), (-1, en_seq_len))
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """
            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        def create_inital_state(inputs, hidden_size):
            # We are not using initial states, but need to pass something to K.rnn funciton
            fake_state = K.zeros_like(inputs)  # <= (batch_size, enc_seq_len, latent_dim
            fake_state = K.sum(fake_state, axis=[1, 2])  # <= (batch_size)
            fake_state = K.expand_dims(fake_state)  # <= (batch_size, 1)
            fake_state = K.tile(fake_state, [1, hidden_size])  # <= (batch_size, latent_dim
            return fake_state

        fake_state_c = create_inital_state(encoder_out_seq, encoder_out_seq.shape[-1])
        fake_state_e = create_inital_state(encoder_out_seq, encoder_out_seq.shape[1])  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
import numpy as np  
import pandas as pd 
import re           
from bs4 import BeautifulSoup 
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from nltk.corpus import stopwords   
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
import warnings
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
data=pd.read_csv("../input/hinaguhey/train.csv")
print(data)
# Out:
#                                                                                                                                                                                                   Review Text  \
# 0                                                                                            Did nothing for me, didn't help lost even with working out and eating healthy. Didn't curb appetite or anything.
# 1                                                                                            Did nothing for me, didn't help lost even with working out and eating healthy. Didn't curb appetite or anything.
# 2     I have bought these bags and  immediately open one put in some trash and the bag was split down the side. So I opened another bag to cover the split bag and it also split down the side(x3).Don’t b...
# 3                                                                                                                                                                  Gave me an allergic reaction on my face :(
# 4     These don't compare to the name brand wipes. Family of 5 little kids, we use a lot of wipes. These don't cut through sticky messes and they're small and very thin. Might be ok for wiping down less...
# 5     These don't compare to the name brand wipes. Family of 5 little kids, we use a lot of wipes. These don't cut through sticky messes and they're small and very thin. Might be ok for wiping down less...
# 6     These don't compare to the name brand wipes. Family of 5 little kids, we use a lot of wipes. These don't cut through sticky messes and they're small and very thin. Might be ok for wiping down less...
# 7                                                                                                                                                                                                     No good
# 8     These are EXTREMELY hard to swallow. The pills are huge and the sides are sharp. I seriously feel like i can choke on them. I don’t know about their effects and honestly don’t care because it’s no...
# 9     First of all the style I am leaving a review for is: Solimo incontinent Maximum Absorbency Long Length individually wrapped.<br />I had always used a name brand but still had to search for somethi...
# 10    First of all the style I am leaving a review for is: Solimo incontinent Maximum Absorbency Long Length individually wrapped.<br />I had always used a name brand but still had to search for somethi...
# 11    First of all the style I am leaving a review for is: Solimo incontinent Maximum Absorbency Long Length individually wrapped.<br />I had always used a name brand but still had to search for somethi...
# 12    These smelled horrible! As soon as I opened the bottle I was hit by a smell of ammonia or perm solution. I don’t know if this is just how these smell or if something was wrong with them but I was ...
# 13                                                                                                           Super easy these don’t work and definitely doesn’t give you energy. I’ll stick with GNC instead.
# 14                                                                                                           Super easy these don’t work and definitely doesn’t give you energy. I’ll stick with GNC instead.
# 15    By my lights, these are a big disappointment.  Finding good veggie vitamins isn’t always easy.  And the convenience of gummies was appealing.  But:  these have a lot of sugars in them, and a lot o...
# 16    By my lights, these are a big disappointment.  Finding good veggie vitamins isn’t always easy.  And the convenience of gummies was appealing.  But:  these have a lot of sugars in them, and a lot o...
# 17                                                                                                                                     Absolutely did not improve my health at all in any way, shape or form.
# 18    I was having neck surgery and thought I would stock up. My last order was a big one and whe n I opened second Pack the expiration date was just two weeks away! I couldn't drink all of them and now...
# 19    I don't know why the ratings are so high for this - I have used so many different brands of lavender essential oils, from high quality Aura Cacia to cheaper lesser known "X Brand" brands -  none o...
# 20    I don't know why the ratings are so high for this - I have used so many different brands of lavender essential oils, from high quality Aura Cacia to cheaper lesser known "X Brand" brands -  none o...
# 21    I don't know why the ratings are so high for this - I have used so many different brands of lavender essential oils, from high quality Aura Cacia to cheaper lesser known "X Brand" brands -  none o...
# 5951  Solid protein. Aminogen version. Not enough chocolate. LIST THE PRICE ACCURATELY
# 5952  Solid protein. Aminogen version. Not enough chocolate. LIST THE PRICE ACCURATELY
# 5953  Solid protein. Aminogen version. Not enough chocolate. LIST THE PRICE ACCURATELY
# 5954                                                                   So disappointed
# 5955                                                                 They smell awful!
# 5956                                                                 They smell awful!
# 5957                                                                             Nasty
# 5958                                                                             Taste
#
#                        topic
# 0      Shipment and delivery
# 1              Not Effective
# 2           Customer Service
# 3                   Allergic
# 4                    Texture
# 5       Quality/Contaminated
# 6          Color and texture
# 7           Bad Taste/Flavor
# 8         Too big to swallow
# 9       Quality/Contaminated
# 10                   Texture
# 11         Color and texture
# 12                Smells Bad
# 13                   Texture
# 14             Not Effective
# 15                 Too Sweet
# 16               Ingredients
# 17             Not Effective
# 18                    Expiry
# 19      Quality/Contaminated
# 20                Smells Bad
# 21          Customer Service
# 22                Smells Bad
# 23                 Packaging
# 24      Quality/Contaminated
# 25          Bad Taste/Flavor
# 26                   Texture
# 27             Not Effective
# 28    Wrong Product received
# 29        Too big to swallow
# ...                      ...
# 5929        Bad Taste/Flavor
# 5930    Quality/Contaminated
# 5931        Bad Taste/Flavor
# 5932               Packaging
# 5933   Shipment and delivery
# 5934   Shipment and delivery
# 5935               Packaging
# 5936                Allergic
# 5937        Bad Taste/Flavor
# 5938               Packaging
# 5939        Customer Service
# 5940           Not Effective
# 5941               Too Sweet
# 5942    Quality/Contaminated
# 5943             Ingredients
# 5944        Bad Taste/Flavor
# 5945               Packaging
# 5946           Not Effective
# 5947           Not Effective
# 5948        Bad Taste/Flavor
# 5949   Shipment and delivery
# 5950   Shipment and delivery
# 5951               Too Sweet
# 5952        Bad Taste/Flavor
# 5953                Allergic
# 5954               Packaging
# 5955              Smells Bad
# 5956        Bad Taste/Flavor
# 5957        Bad Taste/Flavor
# 5958        Bad Taste/Flavor
#
# [5959 rows x 3 columns]

# %%
#data.drop_duplicates(subset=['Review Text'],inplace=True)  #dropping duplicates
#data.dropna(axis=0,inplace=True)   #dropping na

# %%
contraction_mapping = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",

                           "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",

                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",

                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",

                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",

                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",

                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",

                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",

                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",

                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",

                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",

                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",

                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",

                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",

                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",

                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",

                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",

                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",

                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",

                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",

                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",

                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",

                           "you're": "you are", "you've": "you have"}

# %%
data['Review Text'][:10]
# Out:
# 0                                                                                           Did nothing for me, didn't help lost even with working out and eating healthy. Didn't curb appetite or anything.
# 1                                                                                           Did nothing for me, didn't help lost even with working out and eating healthy. Didn't curb appetite or anything.
# 2    I have bought these bags and  immediately open one put in some trash and the bag was split down the side. So I opened another bag to cover the split bag and it also split down the side(x3).Don’t b...
# 3                                                                                                                                                                 Gave me an allergic reaction on my face :(
# 4    These don't compare to the name brand wipes. Family of 5 little kids, we use a lot of wipes. These don't cut through sticky messes and they're small and very thin. Might be ok for wiping down less...
# 5    These don't compare to the name brand wipes. Family of 5 little kids, we use a lot of wipes. These don't cut through sticky messes and they're small and very thin. Might be ok for wiping down less...
# 6    These don't compare to the name brand wipes. Family of 5 little kids, we use a lot of wipes. These don't cut through sticky messes and they're small and very thin. Might be ok for wiping down less...
# 7                                                                                                                                                                                                    No good
# 8    These are EXTREMELY hard to swallow. The pills are huge and the sides are sharp. I seriously feel like i can choke on them. I don’t know about their effects and honestly don’t care because it’s no...
# 9    First of all the style I am leaving a review for is: Solimo incontinent Maximum Absorbency Long Length individually wrapped.<br />I had always used a name brand but still had to search for somethi...
# Name: Review Text, dtype: object

# %%
stop_words = set(stopwords.words('english')) 
def text_cleaner(text):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    tokens = [w for w in newString.split() if not w in stop_words]
    long_words=[]
    for i in tokens:
        if len(i)>=3:                  #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

cleaned_text = []
for t in data['Review Text']:
    cleaned_text.append(text_cleaner(t))

# %%
data['topic'][:10]
# Out:
# 0    Shipment and delivery
# 1            Not Effective
# 2         Customer Service
# 3                 Allergic
# 4                  Texture
# 5     Quality/Contaminated
# 6        Color and texture
# 7         Bad Taste/Flavor
# 8       Too big to swallow
# 9     Quality/Contaminated
# Name: topic, dtype: object

# %%
def summary_cleaner(text):
    newString = re.sub('"','', text)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString)
    newString = newString.lower()
    tokens=newString.split()
    newString=''
    for i in tokens:
        if len(i)>1:                                 
            newString=newString+i+' '  
    return newString

#Call the above function
cleaned_summary = []
for t in data['topic']:
    cleaned_summary.append(summary_cleaner(t))

data['cleaned_text']=cleaned_text
data['cleaned_summary']=cleaned_summary
data['cleaned_summary'].replace('', np.nan, inplace=True)
data.dropna(axis=0,inplace=True)

# %%
data['cleaned_summary'] = data['cleaned_summary'].apply(lambda x : '_START_ '+ x + ' _END_')

# %%
print("Review:",data['cleaned_text'][5])
# Out:
# Review: compare name brand wipes family little kids use lot wipes cut sticky messes small thin might wiping less often used places good tackling actual messes also care lemon scent felt strong

# %%
for i in range(5):
    print("Review:",data['cleaned_text'][i])
    print("Summary:",data['cleaned_summary'][i])
    print("\n")
# Out:
# Review: nothing help lost even working eating healthy curb appetite anything
# Summary: _START_ shipment and delivery  _END_
#
#
# Review: nothing help lost even working eating healthy curb appetite anything
# Summary: _START_ not effective  _END_
#
#
# Review: bought bags immediately open one put trash bag split side opened another bag cover split bag also split side buy end throwing box away
# Summary: _START_ customer service  _END_
#
#
# Review: gave allergic reaction face
# Summary: _START_ allergic  _END_
#
#
# Review: compare name brand wipes family little kids use lot wipes cut sticky messes small thin might wiping less often used places good tackling actual messes also care lemon scent felt strong
# Summary: _START_ texture  _END_

# %%
import matplotlib.pyplot as plt
text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in data['cleaned_text']:
      text_word_count.append(len(i.split()))

for i in data['cleaned_summary']:
      summary_word_count.append(len(i.split()))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})
length_df.hist(bins = 30)
plt.show()

# %%
max_len_text=35
max_len_summary=5

# %%
from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(data['cleaned_text'],data['cleaned_summary'],test_size=0.1,random_state=0,shuffle=True)

# %%
#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr,  maxlen=max_len_text, padding='post') 
x_val   =   pad_sequences(x_val, maxlen=max_len_text, padding='post')

x_voc_size   =  len(x_tokenizer.word_index) +1

# %%
#preparing a tokenizer for summary on training data 
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(y_tr))

#convert summary sequences into integer sequences
y_tr    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr, maxlen=max_len_summary, padding='post')
y_val   =   pad_sequences(y_val, maxlen=max_len_summary, padding='post')

y_voc_size  =   len(y_tokenizer.word_index) +1

# %%
from keras import backend as K 
K.clear_session() 
latent_dim = 500 

# Encoder 
encoder_inputs = Input(shape=(max_len_text,)) 
enc_emb = Embedding(x_voc_size, latent_dim,trainable=True)(encoder_inputs) 

#LSTM 1 
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb) 

#LSTM 2 
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1) 

#LSTM 3 
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True) 
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2) 

# Set up the decoder. 
decoder_inputs = Input(shape=(None,)) 
dec_emb_layer = Embedding(y_voc_size, latent_dim,trainable=True) 
dec_emb = dec_emb_layer(decoder_inputs) 

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True) 
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c]) 

#Attention Layer
attn_layer = AttentionLayer(name='attention_layer') 
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs]) 

# Concat attention output and decoder LSTM output 
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#Dense layer
decoder_dense = TimeDistributed(Dense(y_voc_size, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input) 

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs) 
model.summary()
# Out:
# WARNING: Entity <function rnn at 0x7f8b6157f9d8> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: The global keyword is not yet supported.
# WARNING: Entity <function rnn at 0x7f8b6157f9d8> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: The global keyword is not yet supported.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 35)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 35, 500)      3823500     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 35, 500), (N 2002000     embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 35, 500), (N 2002000     lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 500)    20000       input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 35, 500), (N 2002000     lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 500),  2002000     embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 500),  500500      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 1000)   0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 40)     40040       concat_layer[0][0]
# ==================================================================================================
# Total params: 12,392,040
# Trainable params: 12,392,040
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

# %%
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[es],batch_size=512, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Train on 5363 samples, validate on 596 samples
# Epoch 1/50
# 5363/5363 [==============================] - 9s 2ms/sample - loss: 3.2415 - val_loss: 2.0477
# Epoch 2/50
# 5363/5363 [==============================] - 4s 691us/sample - loss: 1.7873 - val_loss: 1.6044
# Epoch 3/50
# 5363/5363 [==============================] - 4s 674us/sample - loss: 1.3453 - val_loss: 1.1521
# Epoch 4/50
# 5363/5363 [==============================] - 4s 677us/sample - loss: 0.9767 - val_loss: 0.8379
# Epoch 5/50
# 5363/5363 [==============================] - 4s 688us/sample - loss: 0.7595 - val_loss: 0.7311
# Epoch 6/50
# 5363/5363 [==============================] - 4s 682us/sample - loss: 0.6637 - val_loss: 0.6323
# Epoch 7/50
# 5363/5363 [==============================] - 4s 677us/sample - loss: 0.6021 - val_loss: 0.6247
# Epoch 8/50
# 5363/5363 [==============================] - 4s 661us/sample - loss: 0.5871 - val_loss: 0.5973
# Epoch 9/50
# 5363/5363 [==============================] - 4s 691us/sample - loss: 0.5532 - val_loss: 0.5855
# Epoch 10/50
# 5363/5363 [==============================] - 4s 692us/sample - loss: 0.5467 - val_loss: 0.5770
# Epoch 11/50
# 5363/5363 [==============================] - 4s 679us/sample - loss: 0.5290 - val_loss: 0.5732
# Epoch 12/50
# 5363/5363 [==============================] - 4s 713us/sample - loss: 0.5068 - val_loss: 0.5797
# Epoch 00012: early stopping

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 
pyplot.legend() 
pyplot.show()

# %%
reverse_target_word_index=y_tokenizer.index_word 
reverse_source_word_index=x_tokenizer.index_word 
target_word_index=y_tokenizer.word_index

# %%
# encoder inference
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_len_text,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
[decoder_outputs2] + [state_h2, state_c2])
# Out:
# WARNING: Entity <function rnn at 0x7f8b6157f9d8> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: The global keyword is not yet supported.
# WARNING: Entity <function rnn at 0x7f8b6157f9d8> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: The global keyword is not yet supported.

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Chose the 'start' word as the first word of the target sequence
    target_seq[0, 0] = target_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        #print(output_tokens)
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        #print(sampled_token_index)
        if sampled_token_index==0:
            sampled_token_index=1
            
        sampled_token = reverse_target_word_index[sampled_token_index]
        #print(sampled_token)

        if(sampled_token!='end'):
            if decoded_sentence =='':
                decoded_sentence=sampled_token
            else:
                decoded_sentence +=' '+sampled_token
                
                
      

            # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'end' or len(decoded_sentence.split()) >= (max_len_summary-1)):
                stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
      if((i!=0 and i!=target_word_index['start']) and i!=target_word_index['end']):
        newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
      if(i!=0):
        newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(len(x_val)):
  print("Review:",seq2text(x_val[i]))
  print("Original summary:",seq2summary(y_val[i]))
  print("Predicted summary:",decode_sequence(x_val[i].reshape(1,max_len_text)))
  print("\n")
# Out:
# Review: granddaughter hated
# Original summary: bad taste flavor
# Predicted summary: not effective
#
#
# Review: order came content empty envelope help brand thanks thanks
# Original summary: packaging
# Predicted summary: packaging
#
#
# Review: capsules worked tablet form work disappointing missed return date would send back
# Original summary: packaging
# Predicted summary: not effective
#
#
# Review: product cheap work well ones noticed powder dissolve water like one
# Original summary: inferior to competitors
# Predicted summary: not effective
#
#
# Review: unfortunately bottles damaged broken caps leaked throughout box
# Original summary: packaging
# Predicted summary: packaging
#
#
# Review: seem pretty good multivitamin warned squeamish strong fish oil smell taste far able swallow ever nauseous think would able handle used brands dha strong fishy odor sure problem coating source dha causes funkiness
# Original summary: allergic
# Predicted summary: quality contaminated
#
#
# Review: product arrived dried emailed seller still response week
# Original summary: packaging
# Predicted summary: packaging
#
#
# Review: know possible mess orange flavor pleasant plus texture chalky tums like ordering struggling even get jar
# Original summary: smells bad
# Predicted summary: bad taste flavor
#
#
# Review: although products seem excellent product advertised absolutely assistance falling asleep staying asleep quality sleep however stomach waste money overall
# Original summary: not effective
# Predicted summary: bad taste flavor
#
#
# Review: disappointed took one capsule insomnia night stomach cramps diarrhea needless say little sleep certainly work using product
# Original summary: allergic
# Predicted summary: not effective
#
#
# Review: flavor great texture awful way mushy soft like gummies
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: package breaking open upon arrival please replace
# Original summary: packaging
# Predicted summary: packaging
#
#
# Review: says delivered never delivered
# Original summary: shipment and delivery
# Predicted summary: shipment and delivery
#
#
# Review: arrive
# Original summary: customer service
# Predicted summary: not effective
#
#
# Review: gave bad stomach cramps bloating hours felt miserable like huge log stomach
# Original summary: allergic
# Predicted summary: bad taste flavor
#
#
# Review: order product april expected date delivery may today june still received send emails response vendor paid action taken notes keep changing think may lost running late etc etc
# Original summary: shipment and delivery
# Predicted summary: packaging
#
#
# Review: put mouth taste smell appalling idea using every day excite taken cbd liquid drop tongue tastes bad worse take see well works update abuse itcoukd perfectly good product work wonderfully hard get past taste odor
# Original summary: quality contaminated
# Predicted summary: bad taste flavor
#
#
# Review: star worked well decided spend little money thinking expensive product would provide better results right wrong noticeable difference energy libido stamina etc herbal mixture seems react well digested leaving horrible aftertaste time try something else
# Original summary: bad taste flavor
# Predicted summary: not effective
#
#
# Review: bags thick enough opening way big hug garbage bag constantly falling reach pull wrap back around garbage half time bag gets messy stuff garbage gross hate never issue name brand bags
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review
# Original summary: quality contaminated
# Predicted summary: not effective
#
#
# Review: last long time couple joggs read gives eight servings scooper thing huge guess weight gainer measured work used breakfast start work going cook breakfast time held till service purpose found allergic egg sell rest mine
# Original summary: too big to swallow
# Predicted summary: bad taste flavor
#
#
# Review: mix well tastes unpleasant either way keeps full feel healthy taking
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: taken product month wonderful seem like product broken capsules strange packaging affects believe real product need refund
# Original summary: packaging
# Predicted summary: bad taste flavor
#
#
# Review: flavor horrible tried bullet coffee struggled drink half convenience powder good taste nope purchase buy brand still wanted post review
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: came opened already opened powder burst container two stars love product packaging damaged
# Original summary: packaging
# Predicted summary: packaging
#
#
# Review: tried protein mixes least favorite texture flavor left lot desired
# Original summary: color and texture
# Predicted summary: bad taste flavor
#
#
# Review: really find misleading would put high absorption small vitamin notice difference health taking
# Original summary: false advertisement
# Predicted summary: packaging
#
#
# Review: essential oils tampered usually buy essential oils wholefoods bought online whim bad mistake seal broken bottles oil diluted something else cannot smell barely smell anything reporting company brand false advertising scam
# Original summary: packaging
# Predicted summary: quality contaminated
#
#
# Review: found black object inside gummy buy brand anymore
# Original summary: customer service
# Predicted summary: bad taste flavor
#
#
# Review: ordered aller tec pills pills one years worth day expire months arrived expire months count expiry month january thank brand making return super easy
# Original summary: expiry
# Predicted summary: bad taste flavor
#
#
# Review: body seem like form gave headache works better headache
# Original summary: allergic
# Predicted summary: bad taste flavor
#
#
# Review: brand usually reliable zinc gets stuck throat disintegrates mouth bad
# Original summary: texture
# Predicted summary: bad taste flavor
#
#
# Review: sorry ever ordered anything brand many items never received item review give positive review never received product
# Original summary: shipment and delivery
# Predicted summary: packaging
#
#
# Review: broke soooo bad recommend
# Original summary: quality contaminated
# Predicted summary: not effective
#
#
# Review: good helping heartburn soft laxative counts supplement need help low mag levels get chelated amino better switch alkaline water recommend something like stage zen system electric machines dont add minerals improve level
# Original summary: customer service
# Predicted summary: allergic
#
#
# Review: work strict keto diet think stalled weight loss lost weight started taking stopped
# Original summary: shipment and delivery
# Predicted summary: not effective
#
#
# Review: receive yet
# Original summary: shipment and delivery
# Predicted summary: shipment and delivery
#
#
# Review: contains pretty much every bad ingredient legally put food product buy
# Original summary: quality contaminated
# Predicted summary: bad taste flavor
#
#
# Review: fan flavor
# Original summary: bad taste flavor
# Predicted summary: not effective
#
#
# Review: guess rubbery coating pills causes get stuck throat hard time swallowing regular size fish oil pills ordered smaller going continue try choke evidently people swallow hopefully order one
# Original summary: ingredients
# Predicted summary: quality contaminated
#
#
# Review: strawberry flavor tastes fish truly awful
# Original summary: ingredients
# Predicted summary: bad taste flavor
#
#
# Review: denying days drinking replace one meal day starts giving terrible stomach cramps bloating literally keep lot night pain third time years tried sure enough days later pain wondering heck product anyone else get digestive troubles
# Original summary: allergic
# Predicted summary: not effective
#
#
# Review: protein powder use mocha flavor tastes delicious though powder mixes great consistency water blender bottle oat issue give five stars warn anyone peanut allergy possible could cross react chickpea powder formula basically read ingredient buying
# Original summary: texture
# Predicted summary: allergic
#
#
# Review: tried immediately cancel oder denied buyer showed snail mail melted giant gel cap mess seller reputable would canceled order said tried cancel immediately denied saying already shipped already shipped less minute gonna file complaint brand
# Original summary: customer issues
# Predicted summary: quality contaminated
#
#
# Review: leaks every time try spray instead spray get instantly leaks seems like terrible waste product actually get maybe half product paid order
# Original summary: customer service
# Predicted summary: packaging
#
#
# Review: foods really liked pretty excited try one far things put tasted anything like tropical fruit got quite bit chemical medicinal taste use much still experimenting hoping find something work well moment honestly say flavor buying
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: one thing really dislike flavor hoping affects would make end work tried morning tried sleeping food nothing mom would try fall asleep later day really wanted work disappointed
# Original summary: not effective
# Predicted summary: not effective
#
#
# Review: got sick
# Original summary: allergic
# Predicted summary: not effective
#
#
# Review: like scent moisturize without skin irritation however goes greasy takes forever fully absorb two hours later skin still feels sticky also residue left behind like much brands
# Original summary: color and texture
# Predicted summary: bad taste flavor
#
#
# Review: never delivered
# Original summary: shipment and delivery
# Predicted summary: shipment and delivery
#
#
# Review: gross aftertaste tried ton stuff always artificial aftertaste
# Original summary: bad taste flavor
# Predicted summary: not effective
#
#
# Review: love flavor bottle leaks purchased product times bottles leaked product way expensive leak every time use buy
# Original summary: quality contaminated
# Predicted summary: bad taste flavor
#
#
# Review: jar lids cracked almond butter leaked everywhere buy unable return receive credit back normally brand orime
# Original summary: customer service
# Predicted summary: packaging
#
#
# Review: pills way big people swallow last one took got stuck throat fortunately able cough cutting still pretty big sharp edges
# Original summary: too big to swallow
# Predicted summary: bad taste flavor
#
#
# Review: praline pecans came stuck container stale old tasted horrible disappointed cannot believe would sell customers unacceptable buy
# Original summary: smells bad
# Predicted summary: packaging
#
#
# Review: good clean taste mixed water breakfast shakes affect flavor either started taking pcos along folic acid month ago three stars noticed difference tastes good dissolves totally best price
# Original summary: bad taste flavor
# Predicted summary: quality contaminated
#
#
# Review: service great arrived quickly however tangerine flavor almost taste sweet brands delicious orange tangerine flavor would purchase
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: going get prime day deal read ingredients never buy known carcinogens supposed keep healthy give cancer bht derived butane causes cancer dyes yellow promote artificial flavors gluten bad cannot say carcinogens
# Original summary: bad taste flavor
# Predicted summary: quality contaminated
#
#
# Review: package never arrived seller refuses anything big waste money time
# Original summary: shipment and delivery
# Predicted summary: shipment and delivery
#
#
# Review: received expired month gums stuck together dry buy product seller look pharmacy seller
# Original summary: customer service
# Predicted summary: packaging
#
#
# Review: super easy work definitely give energy stick gnc instead
# Original summary: not effective
# Predicted summary: not effective
#
#
# Review: switched different brand probiotics like brand worked bloated able use restroom week rest immediately
# Original summary: not effective
# Predicted summary: not effective
#
#
# Review: love aminos thought would try natural version somehow tasted even chemical tried mixing flavors less powder could make drink flavor
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: fish smell get smell hands nose bottles purchased fine consistency wrote company said refund without receipt said fine asking refund explanation never got response assuming spoiled odor worth risk wasting money get another brand depend
# Original summary: ingredients
# Predicted summary: allergic
#
#
# Review: avoid products think low quality sometimes finances force use stuff however products gone bad year early half bottle nac brown splotches inside normally white pills took anyway like idiot good til made nauseous waste money
# Original summary: quality contaminated
# Predicted summary: quality contaminated
#
#
# Review: give chance opened saw felt cheap wrinkly paper uncomfortable wear kind like old pads used wear tried one anyway small accident else would need right well accident went right leg pad could absorb sad sad
# Original summary: pricing
# Predicted summary: bad taste flavor
#
#
# Review: fair slept better product easy take tasted good however next day felt incredibly weird unwell gave product try side effect benefits
# Original summary: texture
# Predicted summary: not effective
#
#
# Review: like taste sweet
# Original summary: bad taste flavor
# Predicted summary: not effective
#
#
# Review: really like taste taste like medicine plus sugar buy anymore even though organic
# Original summary: quality contaminated
# Predicted summary: bad taste flavor
#
#
# Review: pills sticky must broken open bottle problem know return date past
# Original summary: color and texture
# Predicted summary: packaging
#
#
# Review: like products big fail one work raised blood pressure slightly nauseating produce energy claimed expected find another source
# Original summary: allergic
# Predicted summary: not effective
#
#
# Review: safety seal broken guessing taken poisoned something ordered service matters
# Original summary: customer service
# Predicted summary: packaging
#
#
# Review: love diapers longer buying price gone less two months
# Original summary: too big to swallow
# Predicted summary: bad taste flavor
#
#
# Review: sent box missing two laxaherb disappointed
# Original summary: packaging
# Predicted summary: packaging
#
#
# Review: bag said would replace cost throw smashed product away recieved new item charged replacement return broken item spent min phone getting refund refunded additional charge would let return whole order want product waste time money
# Original summary: packaging
# Predicted summary: packaging
#
#
# Review: throw away vitamins hard chewable never problem buying local grocery store
# Original summary: smells bad
# Predicted summary: packaging
#
#
# Review: box came equally large styrofoam cooler ice pack small one jar fiber gummies inside let get store miles away stop hope brand packaging companies look doubt really perishable product needed huge packaging size plastic bottle
# Original summary: too big to swallow
# Predicted summary: packaging
#
#
# Review: vegan vitamins important also need vitamins easy digest vitamins hard stomach take nausea medications since expensive finished bottle buy
# Original summary: customer service
# Predicted summary: bad taste flavor
#
#
# Review: husband zinc supplements tastes like tic tacs much zinc aftertaste zinc important tissue repair great skin nurse seen people healing slowly would add zinc vitamin regimen would heal much faster really helped decubitus patients lot
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: works fine moisturizer sunscreen smell husband notice certainly sensitive fragrances might right choice amount per pump right tad oily shiny applied wish could ignore scent stick neutrogena
# Original summary: texture
# Predicted summary: bad taste flavor
#
#
# Review: taking close months zero relief pain knee total waste money
# Original summary: not effective
# Predicted summary: not effective
#
#
# Review: bad product energy pump
# Original summary: quality contaminated
# Predicted summary: packaging
#
#
# Review: started taking every day weeks lactose intolerance returned vengeance nonstop digestive issues past days say conclusively probiotic blame gonna stop taking back billion cfu read taking many probiotics cause nausea diarrhea billion good daily intake
# Original summary: not effective
# Predicted summary: allergic
#
#
# Review: product arrived vitamins stuck together difficult separate sure buy brand
# Original summary: not effective
# Predicted summary: packaging
#
#
# Review: natural lemon flavor heartburn stay away
# Original summary: allergic
# Predicted summary: bad taste flavor
#
#
# Review: recommend first bottle received fine next awful fish smell gagging left hands smelling like fish even washing tried vitamin anyway twice ended diarrhea times happen first bottle thought issue purchasing brand problem bottle purchased walgreens
# Original summary: allergic
# Predicted summary: packaging
#
#
# Review: goodness pungent stink entire bathroom every time open bottle make breath smell horrible take people life noticed immediately kept asking stinks bad bathroom smell funny taken complexes nasty rotten egg meets roadkill smell going pass
# Original summary: quality contaminated
# Predicted summary: not effective
#
#
# Review: expensive get local gnc promotion
# Original summary: pricing
# Predicted summary: not effective
#
#
# ...
# Original summary: not effective
# Predicted summary: not effective
#
#
# Review: used another brand gummy vitamins around years tried brand gummies good texture flavor repulsive surprised bad gummy could
# Original summary: color and texture
# Predicted summary: bad taste flavor
#
#
# Review: reorder item brand fulfillment sent hat instead food solutions fault somebody fulfillment pulled wrong item check
# Original summary: wrong product received
# Predicted summary: packaging
#
#
# Review: large impossible swallow whole break half feel like cutting throat swallowing order
# Original summary: too big to swallow
# Predicted summary: quality contaminated
#
#
# Review: arrived last week product extremely stale hard chewy given vendor consistently delivers stale product cannot recommend purchase brand olly vitamins purchase local druggist much better fresh collagen done wonders skin nails recommended olly quite people
# Original summary: smells bad
# Predicted summary: packaging
#
#
# Review: like texture got stuck teeth flavor okay reordering
# Original summary: quality contaminated
# Predicted summary: bad taste flavor
#
#
# Review: soap leaked inside bag know much lost cannot recycle bag
# Original summary: shipment and delivery
# Predicted summary: packaging
#
#
# Review: scoop size compared optimum nutrition total number servings within container substantially lower comprable optimum nutrition product weight aside product seem general quality optimum nutrition also great taste likely continue buy products cycling one ongoing basis
# Original summary: false advertisement
# Predicted summary: bad taste flavor
#
#
# Review: order whole psyllium husks received psyllium husk powder course arrived foolishly assumed item ordered went ahead broke safety seal open container returnable powder effective whole husks
# Original summary: packaging
# Predicted summary: not effective
#
#
# Review: used twice weird film started appearing around edge bottle
# Original summary: texture
# Predicted summary: not effective
#
#
# Review: product never arrived ordered weeks ago still transit option receive refund ability communicate brand need refund
# Original summary: shipment and delivery
# Predicted summary: packaging
#
#
# Review: gross smelling tasting texture different gummy vitamins tried many women daily multis huge hard swallow thought gummies would better regret purchase
# Original summary: color and texture
# Predicted summary: bad taste flavor
#
#
# Review: may work know personally protein powder taste good make excuses end getting protein requirements protein powder using years gold standard casein chocolate supreme flavor truthfully even time look forward daily servings tasty water think stick
# Original summary: texture
# Predicted summary: not effective
#
#
# Review: feel bad try get reaction know
# Original summary: quality contaminated
# Predicted summary: bad taste flavor
#
#
# Review: horrible burned face giving patchy dark spots caused horrible breakout made break itchy painful hives lasted week
# Original summary: allergic
# Predicted summary: bad taste flavor
#
#
# Review: may work know personally protein powder taste good make excuses end getting protein requirements protein powder using years gold standard casein chocolate supreme flavor truthfully even time look forward daily servings tasty water think stick
# Original summary: quality contaminated
# Predicted summary: not effective
#
#
# Review: listed comparable smarty pants actually compared products smarty pants contains natural methylfolate form folate product contains man made version folic acid people cannot process man made version folic acid read labels know getting
# Original summary: ingredients
# Predicted summary: quality contaminated
#
#
# Review: taste somewhat like cinnamon gritty flavor tho fill satisfied product
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: protein powders reason high calories high sugar carbs content waste money scoop fact humongous dont even know people take scoops time cant even take one scoop overall terrible experience consuming product dont buy never tried
# Original summary: allergic
# Predicted summary: bad taste flavor
#
#
# Review: wrist injury stopped working almost completely returning understand sweeteners good since contain much calories sugar outcome case bad taste cannot get strong artificial sweeteners taste matter try honestly give sugar run extra mile gym worth
# Original summary: bad taste flavor
# Predicted summary: quality contaminated
#
#
# Review: like price quantity kids like strawberry ones
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: bags thin rip easily waste money going back zip brand trust quality bags cheap reason
# Original summary: not effective
# Predicted summary: not effective
#
#
# Review: made gain weight give energy looking
# Original summary: not effective
# Predicted summary: not effective
#
#
# Review: following best results directions intake grams sugar day grams morning later day tasted fine quit using week half due feeling seeing difference except longer keeping weight paid attention labels expect much sugar
# Original summary: too sweet
# Predicted summary: not effective
#
#
# Review: hate give bad review however product took long time get house complaining delivery service product product fine
# Original summary: quality contaminated
# Predicted summary: packaging
#
#
# Review: used first two pregnancies cannot use time think changed formula taste smell fish disgusting cannot keep issue going find new vitamin
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: would call gummies like solidified gel disgusting flavor texture
# Original summary: color and texture
# Predicted summary: bad taste flavor
#
#
# Review: glass bottle broken small shards glass cannot consume cuz dont wanna cut throat wont allow return
# Original summary: packaging
# Predicted summary: packaging
#
#
# Review: return window kept trying get work open right away return window closed foods tells return via order brand stuck use never purchase foods brand one thing say notice bitter using ton disappointed upset inexpensive rich
# Original summary: texture
# Predicted summary: not effective
#
#
# Review: love product brand shipped envelope glass bottle shattered inside threw away pills bottle cutting cost shipping evidently important shipping safety quality
# Original summary: shipment and delivery
# Predicted summary: packaging
#
#
# Review: received package
# Original summary: shipment and delivery
# Predicted summary: packaging
#
#
# Review: well almost making late little frustrating also took entire ziploc bag full protein unfortunately unable tell ingredient caused extremely concerned unsure want put product body set sound safe healthy record emailed company weeks ago responded
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: read comments well smelled ordered based reviews smells like bug good expected
# Original summary: inferior to competitors
# Predicted summary: bad taste flavor
#
#
# Review: difficult swallow lots user friendly options days
# Original summary: too big to swallow
# Predicted summary: bad taste flavor
#
#
# Review: thick easily mix well cold liquids
# Original summary: not effective
# Predicted summary: not effective
#
#
# Review: made started feeling numb arms legs hard sleep
# Original summary: allergic
# Predicted summary: bad taste flavor
#
#
# Review: ordered chocolate consuming three bottles realized case ineas sent expired march stevia taste nasty
# Original summary: expiry
# Predicted summary: bad taste flavor
#
#
# Review: silver chewables gluten free even though listing says think use generic description vitamins listing said verified non gmo gluten free vitamin smooth coating easy swallow read label based listing took awhile figure caused bad reaction
# Original summary: quality contaminated
# Predicted summary: quality contaminated
#
#
# Review: pooper consistency still varies based eaten definitely less gassy taking either kid still burp fart storm lol like flavor though asks every morning least fight take considering another probiotic see gummies ineffective affected much probiotocs
# Original summary: not effective
# Predicted summary: bad taste flavor
#
#
# Review: infections also number lady parts kids one gave degree tear swelling product comparable swelling birth injury hurts bad seen think smith lips benadryl straw mental picture current state vagina like pain product trust day stuff
# Original summary: quality contaminated
# Predicted summary: quality contaminated
#
#
# Review: overpriced per shop locally
# Original summary: pricing
# Predicted summary: bad taste flavor
#
#
# Review: first foremost scalp broke red splotches itchy painful sure way know body taking liking know common reaction ton researching definitely allergic type vitamin mixture one reactions like really concerning additionally harsh stomach trying another brand
# Original summary: allergic
# Predicted summary: quality contaminated
#
#
# Review: tasted like oil oxidized turned rancid stale box good order
# Original summary: smells bad
# Predicted summary: bad taste flavor
#
#
# Review: like purchasing dated product
# Original summary: didn like
# Predicted summary: bad taste flavor
#
#
# Review: ive ordered many bottles bottle pills melted together glob fish oils cannot get bottle
# Original summary: ingredients
# Predicted summary: bad taste flavor
#
#
# Review: taking nature bounty turmeric pills herbal health supplement months pills large easy enough swallow lot water seems lingering flavor however noticed significant improvement change joint pain discovered sweat distinct smell turmeric
# Original summary: not effective
# Predicted summary: bad taste flavor
#
#
# Review: gave horrific nightmares also caused wake suddenly pounding heart confusion tried four times time result threw away
# Original summary: quality contaminated
# Predicted summary: bad taste flavor
#
#
# Review: especially diabetic whopping grams sugar form glucose syrup beet sugar per gummies oxymoron sugar sleep never restful canola oil carnauba wax much better choice knows natural flavors mean better use pure essential oils better sleep
# Original summary: bad taste flavor
# Predicted summary: quality contaminated
#
#
# Review: really miserable chew everyday way way sweet almost choke want trouble returning cheap
# Original summary: too sweet
# Predicted summary: bad taste flavor
#
#
# Review: product date one day tablets could consumed worry though throw rest away never order tablets
# Original summary: expiry
# Predicted summary: quality contaminated
#
#
# Review: taste really bad smell made feel like throwing
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: never received product supposed one day shipping almost month came wrote company said went wrong shipping
# Original summary: shipment and delivery
# Predicted summary: shipment and delivery
#
#
# Review: never received
# Original summary: shipment and delivery
# Predicted summary: shipment and delivery
#
#
# Review: help constipation unless want watery stools also gritty tastes awful
# Original summary: allergic
# Predicted summary: bad taste flavor
#
#
# Review: hot oil taken food hoped enteric coating product would help get capsule stomach contents luck taking full meal lots water still breaks stomach creating quite bit upset lots oregano burps two day cannot say helping
# Original summary: allergic
# Predicted summary: quality contaminated
#
#
# Review: usually comes wrapped nice easy chew flavor nice recent time ordered gummies stuck together small bottle cant take apart kind
# Original summary: texture
# Predicted summary: bad taste flavor
#
#
# Review: receive pictured item
# Original summary: shipment and delivery
# Predicted summary: shipment and delivery
#
#
# Review: purchased product using another htp supplement years bought price usual supplement went way experienced benefits using product product finish bottle afraid end switching back old brand
# Original summary: inferior to competitors
# Predicted summary: bad taste flavor
#
#
# Review: bought men version several times taste great ordered daughter said taste terrible thought kidding tried one nasty texture taste
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: absolutely awful disgusting avoid buying
# Original summary: bad taste flavor
# Predicted summary: not effective
#
#
# Review: year supply ordered replacement hopefully good expiration date time item obviously cannot consumed gets expired believe reputable business never ship costumer hope one single incident individual mistake plan come back change review replacement item arrives
# Original summary: expiry
# Predicted summary: expiry
#
#
# Review: taste horrible taste flavors chalk taste also huge chew
# Original summary: too big to swallow
# Predicted summary: bad taste flavor
#
#
# Review: worse yet texture extremely rubbery hard chew reminds must like chew pencil eraser also poor value gummy format supplements nearly always cost pills fact gummies fail taste texture gives value pill puts rating star recommended
# Original summary: color and texture
# Predicted summary: quality contaminated
#
#
# Review: horrible taste waste money
# Original summary: bad taste flavor
# Predicted summary: not effective
#
#
# Review: allergic vitafusion womens multi
# Original summary: allergic
# Predicted summary: not effective
#
#
# Review: first time buying product reading many bad reviews product contains contaminants never buy taste stevia horrible wish never bought product
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: huge pill worst ingredients found supplements including mannitol sobitol sorbitol anhydrides soy lecithin titanium dioxide color
# Original summary: too big to swallow
# Predicted summary: bad taste flavor
#
#
# Review: used first two pregnancies cannot use time think changed formula taste smell fish disgusting cannot keep issue going find new vitamin
# Original summary: ingredients
# Predicted summary: bad taste flavor
#
#
# Review: gave stars cause price amount good hard wipe overall good household girls
# Original summary: quality contaminated
# Predicted summary: bad taste flavor
#
#
# Review: please cover product lot number expiration date
# Original summary: expiry
# Predicted summary: packaging
#
#
# Review: item description product says bottles purchase price received bottle difficulty getting seller without return first bottle need like get bottle advertised get money refunded got half order
# Original summary: shipment and delivery
# Predicted summary: packaging
#
#
# Review: taste horrible point blank period tried mix scoops bad idea use scoops taste bad need mix stuff fruits etc help taste
# Original summary: quality contaminated
# Predicted summary: bad taste flavor
#
#
# Review: allergic reaction vitamin scary home kids arms chest broke hot red rash sure missed reviews said
# Original summary: allergic
# Predicted summary: packaging
#
#
# Review: used brand years supplements definitely good metamucil even doubling work well using months thought could dietary intake changing things varied foods meals habits work like name brand
# Original summary: inferior to competitors
# Predicted summary: not effective
#
#
# Review: cap nice tend drip used product twice notice difference rest cap got disappointing bad
# Original summary: quality contaminated
# Predicted summary: bad taste flavor
#
#
# Review: consistent protein supplement user tried rotating several different brands wanted change flavors ordered one seeing really good reviews ordered vanilla tastes really tastes like fake vanilla weird powering sweetener flavor normally picky one meet expectations
# Original summary: bad taste flavor
# Predicted summary: bad taste flavor
#
#
# Review: listing incorrect ordered returned replacement still sent wrong item ordered according listing item
# Original summary: wrong product received
# Predicted summary: bad taste flavor
#
#
# Review: opened bottle find almost half capsules broken many pieces probiotic powder everywhere
# Original summary: packaging
# Predicted summary: packaging

# %%
test_data=pd.read_csv('../input/hinaguhey/test.csv')

# %%
stop_words = set(stopwords.words('english')) 
def text_cleaner(text):
    newString = text.lower()
    newString = BeautifulSoup(newString, "lxml").text
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = ' '.join([contraction_mapping[t] if t in contraction_mapping else t for t in newString.split(" ")])    
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    tokens = [w for w in newString.split() if not w in stop_words]
    long_words=[]
    for i in tokens:
        if len(i)>=3:                  #removing short word
            long_words.append(i)   
    return (" ".join(long_words)).strip()

cleaned_text = []
for t in test_data['Review Text']:
    cleaned_text.append(text_cleaner(t))

# %%
test_data['cleaned_text']=cleaned_text

# %%
print("Review:",test_data['cleaned_text'][5])
# Out:
# Review: used loyal customer brand using gloves years however opened new box today smell really really really bad never paid attention since smell might strong enough notice disappointed scared since used cut fruits little one everyday use wash dishes

# %%
test_val=test_data['cleaned_text']
#convert text sequences into integer sequences

test_val   =   x_tokenizer.texts_to_sequences(test_val)

#padding zero upto maximum length

test_val   =   pad_sequences(test_val, maxlen=max_len_text, padding='post')

# %%
test_val
# Out:
# array([[  22, 7262, 1248, ...,    0,    0,    0],
#        [  22, 7262, 1248, ...,    0,    0,    0],
#        [ 146,   59,    0, ...,    0,    0,    0],
#        ...,
#        [ 310,  381,  109, ...,    0,    0,    0],
#        [  11, 2296,    7, ...,    0,    0,    0],
#        [  18,   31,    0, ...,    0,    0,    0]], dtype=int32)

# %%
#for i in range(len(test_val)):
    #print("Predicted summary:",decode_sequence(test_val[i].reshape(1,max_len_text)))

# %%
answer=[]
for i in range(len(test_val)):
    answer.append(decode_sequence(test_val[i].reshape(1,max_len_text)))

# %%
test_data['topic']=answer
print(test_data.iloc[2,:])
# Out:
# Review Text     Don’t waste your money.
# Review Title     No change. No results.
# cleaned_text                waste money
# topic                     not effective
# Name: 2, dtype: object

# %%
test_data=test_data.drop(columns='cleaned_text')

# %%
print(test_data.iloc[0,:])
# Out:
# Review Text     I use chia seed in my protein shakes. These tasted like they were moldy. Throw them out
# Review Title                                                                                   Bad tast
# topic                                                                                         packaging
# Name: 0, dtype: object

# %%
test_data.to_csv('solution1.csv')
